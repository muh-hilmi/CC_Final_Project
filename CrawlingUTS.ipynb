# %%
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# Crawl Data

filename = 'anies.csv'
search_keyword = 'anies until:2023-11-5 since:2023-10-5 lang:id'
limit = 200

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sat Nov 04 23:59:15 +0000 2023  1720953887648342166
# 1    Sat Nov 04 23:59:10 +0000 2023  1720953869000478735
# 2    Sat Nov 04 23:59:08 +0000 2023  1720953861115101186
# 3    Sat Nov 04 23:57:58 +0000 2023  1720953565894541375
# 4    Sat Nov 04 23:57:26 +0000 2023  1720953429860770217
# ..                              ...                  ...
# 197  Sat Nov 04 19:39:27 +0000 2023  1720888509920411943
# 198  Sat Nov 04 19:29:06 +0000 2023  1720885904943051071
# 199  Sat Nov 04 19:28:27 +0000 2023  1720885739330875529
# 200  Sat Nov 04 19:21:20 +0000 2023  1720883948572885146
# 201  Sat Nov 04 19:17:01 +0000 2023  1720882864089448695
#
#                                              full_text  quote_count  \
# 0                               @sobat_anies 2. Keliru            0
# 1                                    @dccomm_gov Padat            0
# 2    @islah_bahrawi @kangdede78 Pakar radikal radik...            0
# ...

# %%
num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 202.

# %%
# Crawl Data

filename = 'prabowo.csv'
search_keyword = 'prabowo until:2023-11-5 since:2023-10-5 lang:id'
limit = 200

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
# Crawl Data

filename = 'ganjar.csv'
search_keyword = 'ganjar until:2023-11-5 since:2023-10-5 lang:id'
limit = 200

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
file1 = pd.read_csv('tweets-data/anies.csv', delimiter=";")
file2 = pd.read_csv('tweets-data/ganjar.csv', delimiter=";")
file3 = pd.read_csv('tweets-data/prabowo.csv', delimiter=";")

combined_df = pd.concat([file1, file2, file3], ignore_index=True)
combined_df.to_csv('combined_file.csv', index=False)

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('combined_file.csv')

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sat Nov 04 23:59:15 +0000 2023  1720953887648342166
# 1    Sat Nov 04 23:59:10 +0000 2023  1720953869000478735
# 2    Sat Nov 04 23:59:08 +0000 2023  1720953861115101186
# 3    Sat Nov 04 23:57:58 +0000 2023  1720953565894541375
# 4    Sat Nov 04 23:57:26 +0000 2023  1720953429860770217
# ..                              ...                  ...
# 418  Sat Nov 04 23:59:08 +0000 2023  1720953858837631240
# 419  Sat Nov 04 23:59:01 +0000 2023  1720953831801180608
# 420  Sat Nov 04 23:58:59 +0000 2023  1720953823148245337
# 421  Sat Nov 04 23:58:56 +0000 2023  1720953809630007770
# 422  Sat Nov 04 23:58:51 +0000 2023  1720953786951434636
#
#                                              full_text  quote_count  \
# 0                               @sobat_anies 2. Keliru            0
# 1                                    @dccomm_gov Padat            0
# 2    @islah_bahrawi @kangdede78 Pakar radikal radik...            0
# ...

# %%
full_text_column = df['full_text']
full_text_df = df[['full_text']]

# %%
full_text_df
# Out:
#                                              full_text
# 0                               @sobat_anies 2. Keliru
# 1                                    @dccomm_gov Padat
# 2    @islah_bahrawi @kangdede78 Pakar radikal radik...
# 3    @lengkongtweets @Avolanza Emg otak bengkok lu ...
# 4    Puji Anies Baswedan sebagai Pemimpin Masa Depa...
# ..                                                 ...
# 418  dalam memperkuat sistem ketahanan pangan, meng...
# 419  Begitu pentingnya air bagi kehidupan ini, memb...
# 420  @kananboekankiri @sigitwid Pak prabowo, terima...
# 421  @BANGSAygSUJUD Sedari awal sy tidak percaya Pr...
# 422  Menurut Hari Suprayogi, Direktur Jenderal Sumb...
#
# [423 rows x 1 columns]

# %%
full_text_column.to_csv('full_text.csv', index=False, header=['full_text'])

# %%
from google.colab import files
files.download('full_text.csv')
